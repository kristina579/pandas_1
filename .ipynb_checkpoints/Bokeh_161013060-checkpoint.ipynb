# %% [markdown]
# # 分省指标数据之使用与制图
# * 数据处理+制图 使用[pandas](http://pandas.pydata.org/pandas-docs/stable/install.html)
# * 制图 使用 [bokeh](http://bokeh.pydata.org/en/latest/docs/installation.html)

# %% [markdown]
# ## (1) 取/连结 数据

# %%
import pandas as pd

# %%
df_GDP= pd.read_table("fsnd_GDP_123.csv",
                       encoding = 'utf8',     
                       header = 3,           
                       skiprows = [35,36],    
                       sep =','                
                      )
df_CPI= pd.read_table("fsnd_CPI_123.CSV",
                       encoding = 'utf8',  
                       header = 3,            
                       skiprows = [35,36],
                       sep =','
                      )

# %% [markdown]
# ## (2) 准备 数据  （型态）

# %%
def prepare(df_in, l_variable, l_value):
    df = df_in.copy()
    df.columns = [ int(x.replace('年','')) if x!='地区' else x for x in df.columns]
    years = [ x for x in df.columns if x!='地区'] 
    df_out = pd.melt(df, id_vars=['地区'], value_vars=years)
    df_out.columns = ['地区', l_variable, l_value]
    df_out = df_out.set_index(['地区',  l_variable])
    return (df_out)

# %%
prepare(df_GDP,"年","GDP")
# Out:
#                     GDP
# 地区       年
# 北京市      2015  23014.59
# 天津市      2015  16538.19
# 河北省      2015  29806.11
# 山西省      2015  12766.49
# 内蒙古自治区   2015  17831.51
# 辽宁省      2015  28669.02
# 吉林省      2015  14063.13
# 黑龙江省     2015  15083.67
# 上海市      2015  25123.45
# 江苏省      2015  70116.38
# 浙江省      2015  42886.49
# 安徽省      2015  22005.63
# 福建省      2015  25979.82
# 江西省      2015  16723.78
# 山东省      2015  63002.33
# 河南省      2015  37002.16
# 湖北省      2015  29550.19
# 湖南省      2015  28902.21
# 广东省      2015  72812.55
# 广西壮族自治区  2015  16803.12
# 海南省      2015   3702.76
# 重庆市      2015  15717.27
# 四川省      2015  30053.10
# 贵州省      2015  10502.56
# 云南省      2015  13619.17
# 西藏自治区    2015   1026.39
# 陕西省      2015  18021.86
# 甘肃省      2015   6790.32
# 青海省      2015   2417.05
# 宁夏回族自治区  2015   2911.77
# ...                 ...
# 天津市      2006   4462.74
# 河北省      2006  11467.60
# 山西省      2006   4878.61
# 内蒙古自治区   2006   4944.25
# 辽宁省      2006   9304.52
# 吉林省      2006   4275.12
# 黑龙江省     2006   6211.80
# 上海市      2006  10572.24
# 江苏省      2006  21742.05
# 浙江省      2006  15718.47
# 安徽省      2006   6112.50
# 福建省      2006   7583.85
# 江西省      2006   4820.53
# 山东省      2006  21900.19
# 河南省      2006  12362.79
# 湖北省      2006   7617.47
# 湖南省      2006   7688.67
# 广东省      2006  26587.76
# 广西壮族自治区  2006   4746.16
# 海南省      2006   1065.67
# 重庆市      2006   3907.23
# 四川省      2006   8690.24
# 贵州省      2006   2338.98
# 云南省      2006   3988.14
# 西藏自治区    2006    290.76
# 陕西省      2006   4743.61
# 甘肃省      2006   2277.35
# 青海省      2006    648.50
# 宁夏回族自治区  2006    725.90
# 新疆维吾尔自治区 2006   3045.26
pl.rcParams['font.sans-serif']=['SimHei']
mpl.rcParams['axes.unicode_minus']=False

# %%
# %matplotlib inline
df_p.query("年==2015").plot(kind='scatter', x='CPI', y='GDP', 
          title = 'CPI与GDP的关系：分省数据')

# %% [markdown]
# ## (5) 用 numpy.polyfit 做线性回归

# %%
# Regression Using Pandas and Statsmodels
import numpy as np
x = df_p.query("年==2015")['CPI']
y = df_p.query("年==2015")['GDP']
fit = np.polyfit(x=x , y=y, deg=1)

ax = df_p.query("年==2015").plot(kind='scatter', x='CPI', y='GDP', 
          title = 'CPI与GDP的关系：分省数据')
ax.plot(x, fit[0] * x + fit[1], color='red')
ax.scatter(x, y)

# %% [markdown]
# ## (6) 可视化 使用bokeh 来制图，可交互（HoverTool tooltip）

# %%
# tooltip 工具提示 
df_p['desc'] = df_p.index.get_level_values(0)

# 制图
from bokeh.plotting import figure, output_file, show, output_notebook
from bokeh.models import HoverTool, BoxSelectTool

title = '分省数据' 
xlabel = 'CPI：消费指数' 
ylabel = 'GDP：产值'

hover = HoverTool(
    tooltips=[
        ( '消费指数',  '$x{0,F}'), 
        ( '产值',  '$y{0,F}'),
        ( '地区',  '@desc'  ),
    ]
)

TOOLS = [hover, "pan, wheel_zoom, box_zoom, reset, resize"]
fig = figure(plot_width=800, plot_height=600,
           x_axis_label = xlabel, y_axis_label = ylabel, 
           title=title, tools=TOOLS)

df_plot = df_p.query("年==2015")

fig.circle("CPI", "GDP",
         source = df_plot,
         fill_alpha=0.6, line_color=None, size= 15)

#regression line
xs = [min(df_plot["CPI"]), max(df_plot["CPI"])]
fig.line(x=xs, y=[ fit[0] * x + fit[1] for x in xs] )

output_notebook() # 输出到IPython/Jupyter Notebook，若要输出到他处需调整
#output_file('by_provinces.htm') # 输出到 htm
show(fig)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="00502a9f-46cf-4031-b21f-70756db248f1">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="2c6e4b54-af35-4ecb-b99c-9b2edc04d204"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("2c6e4b54-af35-4ecb-b99c-9b2edc04d204");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("2c6e4b54-af35-4ecb-b99c-9b2edc04d204");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '2c6e4b54-af35-4ecb-b99c-9b2edc04d204' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"6ca5fbac-16fe-4331-9c9e-25494d1a09f5":{"roots":{"references":[{"attributes":{"callback":null},"id":"a35962c1-e591-4d8d-92e5-81dd8b2c3150","type":"DataRange1d"},{"attributes":{"axis_label":"CPI\uff1a\u6d88\u8d39\u6307\u6570","formatter":{"id":"52f557e2-8bd6-4e91-b9d1-19c1d0085307","type":"BasicTickFormatter"},"plot":{"id":"cc2500d9-3e25-4a66-9958-4a3a5be8764e","subtype":"Figure","type":"Plot"},"ticker":{"id":"45b38c91-ac9c-4d88-ada4-3984af392999","type":"BasicTicker"}},"id":"e42c56da-c542-4172-a1df-1fe7ebd7670a","type":"LinearAxis"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ed844de9-41c0-42a5-a99a-c0f5eb601279","type":"Line"},{"attributes":{"overlay":{"id":"0adf7dd8-3c78-43aa-8b8d-5c90f21e8f25","type":"BoxAnnotation"},"plot":{"id":"cc2500d9-3e25-4a66-9958-4a3a5be8764e","subtype":"Figure","type":"Plot"}},"id":"d7310cb3-19f2-4da3-85c8-65d082fd723a","type":"BoxZoomTool"},{"attributes":{"data_source":{"id":"151696ab-65c9-4ad7-972b-c4d9a67b9520","type":"ColumnDataSource"},"glyph":{"id":"2f9f59de-cf61-407b-965c-fdbbadf45a44","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"846b1ade-f068-4592-b2e7-4485bc606577","type":"Circle"},"selection_glyph":null},"id":"e37bfaeb-3fdd-4587-9795-0e6f2e389fa5","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[100.6,102.6],"y":[24312.68804056279,21978.691115472437]}},"id":"2263c8f8-e0cb-4401-a281-4ea72486d27d","type":"ColumnDataSource"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"31f92434-2ef0-4b22-a1a0-e2ee98b0b8d5","type":"HoverTool"},{"id":"964c41ef-7952-4047-a1a1-373fa4ddfbbb","type":"PanTool"},{"id":"4476b8cc-85d9-4daa-81c6-5a6d71164f78","type":"WheelZoomTool"},{"id":"d7310cb3-19f2-4da3-85c8-65d082fd723a","type":"BoxZoomTool"},{"id":"38b6c2cd-e9c3-4a88-b93f-0bdbf333453c","type":"ResetTool"},{"id":"63074399-c854-4905-b796-484b44f2c10b","type":"ResizeTool"}]},"id":"729e5971-0e33-40a2-8ae9-47401d72db67","type":"Toolbar"},{"attributes":{"callback":null},"id":"6f056f2f-5a73-49b5-92af-e9c85dcda754","type":"DataRange1d"},{"attributes":{"plot":{"id":"cc2500d9-3e25-4a66-9958-4a3a5be8764e","subtype":"Figure","type":"Plot"}},"id":"4476b8cc-85d9-4daa-81c6-5a6d71164f78","type":"WheelZoomTool"},{"attributes":{},"id":"5d804f0c-18a5-4688-85ca-7cbbb2ec0104","type":"BasicTickFormatter"},{"attributes":{},"id":"27df27cc-0554-426c-bef2-466d6ec91ac8","type":"ToolEvents"},{"attributes":{"plot":{"id":"cc2500d9-3e25-4a66-9958-4a3a5be8764e","subtype":"Figure","type":"Plot"}},"id":"63074399-c854-4905-b796-484b44f2c10b","type":"ResizeTool"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":15},"x":{"field":"CPI"},"y":{"field":"GDP"}},"id":"846b1ade-f068-4592-b2e7-4485bc606577","type":"Circle"},{"attributes":{"plot":{"id":"cc2500d9-3e25-4a66-9958-4a3a5be8764e","subtype":"Figure","type":"Plot"}},"id":"964c41ef-7952-4047-a1a1-373fa4ddfbbb","type":"PanTool"},{"attributes":{"callback":null,"column_names":["GDP","CPI","desc","\u5730\u533a_\u5e74"],"data":{"CPI":{"__ndarray__":"","dtype":"float64","shape":[31]},"GDP":{"__ndarray__":"" ...

# %%
df_p.index.get_level_values(1)
# Out:
# Int64Index([2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015,
#             ...
#             2006, 2006, 2006, 2006, 2006, 2006, 2006, 2006, 2006, 2006],
#            dtype='int64', name='年', length=310)

# %%
df_p.index.get_level_values(1).min()
# Out:
# 2006

# %% [markdown]
# ## (7) 可视化 使用bokeh 来制图，可交互（slider）

# %%
from bokeh.plotting import figure
from bokeh.io import output_notebook, push_notebook, show
from bokeh.models import CustomJS, Slider,HoverTool, BoxSelectTool
from bokeh.layouts import column

title = '分省数据' 
xlabel = 'CPI：消费指数' 
ylabel = 'GDP：产值大小'
hover = HoverTool(
    tooltips=[
        ( '消费指数',  '$x{0,F}'), 
        ( '产值大小',  '$y{0,F}'),
        ( '地区',  '@desc'  ),
    ]
)

TOOLS = [hover, "pan, wheel_zoom, box_zoom, reset, resize"]

fig = figure(plot_width=800, plot_height=600,
           x_axis_label = xlabel, y_axis_label = ylabel, 
           title=title, tools=TOOLS)

yr_min = df_p.index.get_level_values(1).min()
df_plot = df_p.query("年=={yr}".format(yr=yr_min))
plt = fig.circle("CPI", "GDP",
         source = df_plot,
         fill_alpha=0.6, line_color=None, size= 15)


def update_plot(year):
    #plt.data_source.data = df_p.query("年=={yr}".format(yr=year))
    plt.data_source.data['CPI'] = list(df_p.query("年=={yr}".format(yr=year)).loc[:,['CPI']].iloc[:,0].values)
    plt.data_source.data['GDP'] = list(df_p.query("年=={yr}".format(yr=year)).loc[:,['GDP']].iloc[:,0].values)
    plt.data_source.data['地区_年'] = [(x[0],int(year)) for x in plt.data_source.data['地区_年']]

    push_notebook(handle=bokeh_handle)  
    print (year)
    ##### new notebook cell #####

callback = CustomJS(code="""
if (IPython.notebook.kernel !== undefined) {
    var kernel = IPython.notebook.kernel;
    cmd = "update_plot(" + cb_obj.value + ")";
    kernel.execute(cmd, {}, {});
}
""")

slider = Slider(start=df_p.index.get_level_values(1).min(), 
                end=df_p.index.get_level_values(1).max(),
                value=1,
                step=1,
                title="年",
                callback=callback)
output_notebook()

bokeh_handle = show(column(slider, fig), notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="c828862f-8d51-4146-8ae2-e5120d145b64">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="476e5466-c061-4420-b2c8-8b1aae299aa3"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("476e5466-c061-4420-b2c8-8b1aae299aa3");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("4985017a-9139-48f0-ae48-ce2a278c6e96", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("476e5466-c061-4420-b2c8-8b1aae299aa3");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '476e5466-c061-4420-b2c8-8b1aae299aa3' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"c5301f9e-519d-4ecc-b489-ca39f32d049c":{"roots":{"references":[{"attributes":{"children":[{"id":"6fc83ab1-e0cd-4052-a4bd-781f479958e5","type":"Slider"}]},"id":"2a92af48-647f-4125-9c71-4d44e2c38f5f","type":"WidgetBox"},{"attributes":{"plot":{"id":"b55c520f-4fd3-49da-aae4-9c1c728c3f5d","subtype":"Figure","type":"Plot"},"ticker":{"id":"d556d518-4e6c-455a-a523-cc529a8126f3","type":"BasicTicker"}},"id":"50a4db77-40a8-4110-acb5-8d50e1420fa0","type":"Grid"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":15},"x":{"field":"CPI"},"y":{"field":"GDP"}},"id":"1a0629c9-f033-4136-a1d4-632b4de60527","type":"Circle"},{"attributes":{"children":[{"id":"2a92af48-647f-4125-9c71-4d44e2c38f5f","type":"WidgetBox"},{"id":"b55c520f-4fd3-49da-aae4-9c1c728c3f5d","subtype":"Figure","type":"Plot"}]},"id":"0e5e44d8-c156-4fbd-801f-16e5b8d08962","type":"Column"},{"attributes":{"data_source":{"id":"13c688e5-e7a5-4091-8e0b-22d9951d33db","type":"ColumnDataSource"},"glyph":{"id":"21fc2f24-e65c-4406-819c-fc7ccb7ae916","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"1a0629c9-f033-4136-a1d4-632b4de60527","type":"Circle"},"selection_glyph":null},"id":"a6ce6efc-1293-4097-a830-d5e8c51ce706","type":"GlyphRenderer"},{"attributes":{"axis_label":"CPI\uff1a\u6d88\u8d39\u6307\u6570","formatter":{"id":"6f4ce975-4e0b-40df-b9e0-f358084f7bc1","type":"BasicTickFormatter"},"plot":{"id":"b55c520f-4fd3-49da-aae4-9c1c728c3f5d","subtype":"Figure","type":"Plot"},"ticker":{"id":"d556d518-4e6c-455a-a523-cc529a8126f3","type":"BasicTicker"}},"id":"62fedb35-5e56-4e11-86b5-f1d585a38f95","type":"LinearAxis"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"e678c6bd-b23d-4d35-9340-c5a743912118","type":"HoverTool"},{"id":"794f7cb8-dd09-446f-b3eb-e6a2b2cb75da","type":"PanTool"},{"id":"97b7d9d3-288e-4118-a1af-0a7bb8444d69","type":"WheelZoomTool"},{"id":"3598b32d-661e-4ace-ba56-d963a02a034f","type":"BoxZoomTool"},{"id":"611607f6-b526-4cb8-bd94-0c9e9471f9cb","type":"ResetTool"},{"id":"4488c5d2-af11-418f-9800-63d0d192b6c9","type":"ResizeTool"}]},"id":"8e641db1-ca52-4ecd-bd8b-76096df26629","type":"Toolbar"},{"attributes":{"plot":null,"text":"\u5206\u7701\u6570\u636e"},"id":"6cbbc2cc-0e99-41ee-a8b5-2b6215f62f42","type":"Title"},{"attributes":{"plot":{"id":"b55c520f-4fd3-49da-aae4-9c1c728c3f5d","subtype":"Figure","type":"Plot"}},"id":"97b7d9d3-288e-4118-a1af-0a7bb8444d69","type":"WheelZoomTool"},{"attributes":{},"id":"e79f4329-5854-47aa-86dc-e4fe108563bd","type":"BasicTicker"},{"attributes":{"callback":null},"id":"fedc5369-e50e-4712-a11d-3c34ad91916f","type":"DataRange1d"},{"attributes":{"fill_alpha":{"value":0.6},"fill_color":{"value":"#1f77b4"},"line_color":{"value":null},"size":{"units":"screen","value":15},"x":{"field":"CPI"},"y":{"field":"GDP"}},"id":"21fc2f24-e65c-4406-819c-fc7ccb7ae916","type":"Circle"},{"attributes":{"code":"\nif (IPython.notebook.kernel !== undefined) {\n    var kernel = IPython.notebook.kernel;\n    cmd = \"update_plot(\" + cb_obj.value + \")\";\n    kernel.execute(cmd, {}, {});\n}\n"},"id":"efb7aa1b-e64b-49f3-8f2d-a1310ddb8aca","type":"CustomJS"},{"attributes":{"overlay":{"id":"92591319-bca2-4aae-aa02-ff5ba59b6c6e","type":"BoxAnnotation"},"plot":{"id":"b55c520f-4fd3-49da-aae4-9c1c728c3f5d","subtype":"Figure","type":"Plot"}},"id":"3598b32d-661e-4ace-ba56-d963a02a034f","type":"BoxZoomTool"},{"attributes":{},"id":"d556d518-4e6c-455a-a523-cc529a8126f3","type":"BasicTicker"},{"attributes":{"plot":{"id":"b55c520f-4fd3-49da-aae4-9c1c728c3f5d","subtype":"Figure","type":"Plot"}},"id":"794f7cb8-dd09-446f-b3eb-e6a2b2cb75da","type":"PanTool"},{"attributes":{"callback":null},"id":"66dd2dec-a77a-4e99-a9d0-63b988ac25e0","type":"DataRange1d"},{"attributes":{},"id":"61729c4e-c1ab-4edf-9065-805770d54057","type":"ToolEvents"},{"attributes":{"plot":{"id":"b55c520f-4fd ...
